# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import multiprocessing

# %% [markdown]
# # PREDICTING NORTH AMERICAN VIDEO GAME SALES
#
# ## Table Of Contents
# 1. [Understanding and Preparing](#preprocess)
# 3. [Visualizing the Data](#visualize)
# 4. [Correlation of Features](#correlation)
# 5. [Training our NaiveBayes Model](#trainingModel0)

# %% [markdown]
# ## Understanding and Preparing the Data <a name="preprocess"></a>
#
# First we will be reading in the data which is in a csv file.

# %%
## base_vgs_df ==== Base Video Game Sales DataFrame

base_vgs_df = pd.read_csv('../VideoGameSalesProject2021/Video_Games_Sales_as_at_22_Dec_2016.csv')

base_vgs_df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# Now let us check for any missing or incorrect values and get an idea of the contents in each of the columns.

# %%
## checking for missing values by adding up all missing values in each column
base_vgs_df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher           255
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
base_vgs_df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count   User_Score  \
# count  16719.000000  16719.000000   8137.000000   8137.000000  7590.000000
# mean       0.047332      0.533543     68.967679     26.360821     7.125046
# std        0.186710      1.547935     13.938165     18.980495     1.500006
# min        0.000000      0.010000     13.000000      3.000000     0.000000
# ...

# %% [markdown]
# We can see that the following columns are missing a significant portion of data; Critic_score, critic_count, User_Score, User_Count, Developer, and Rating so we will have to deal with that eventually. Also notice that there are a couple other issues with the data in the columns,
#
# - The max value in Year_of_Release is 2020, which must be pre-release or something of that nature
# - Large difference between the quartiles in all the sales columns

# %%
freq_global_sales = base_vgs_df.groupby("Global_Sales")['Name'].count()

plt.figure(figsize=(10, 6))

plt.plot(freq_global_sales)
plt.ylabel('Number of Games')
plt.xlabel('Global Sales (in millions)')
plt.title('Frequency of Global Sales')
plt.xlim(0, 10)
plt.ylim(0,800)
plt.grid()

# %%
# Out:
# Global_Sales
# 0.01     638
# 0.02    1087
# 0.03     852
# 0.04     651
# 0.05     631
# Name: Platform, dtype: int64

# %%
## create general platform column

base_vgs_df['General_Platform']= base_vgs_df['Platform']

base_vgs_df.loc[base_vgs_df['Platform'] == 'PS3', 'General_Platform'] =  'Sony_Playstation'
base_vgs_df.loc[base_vgs_df['Platform'] == 'PS', 'General_Platform'] = 'Sony_Playstation' 
base_vgs_df.loc[base_vgs_df['Platform'] == 'PS2', 'General_Platform'] = 'Sony_Playstation'
base_vgs_df.loc[base_vgs_df['Platform'] == 'PS4', 'General_Platform'] = 'Sony_Playstation'
base_vgs_df.loc[base_vgs_df['Platform'] == 'PSP', 'General_Platform'] = 'Sony_Playstation'
base_vgs_df.loc[base_vgs_df['Platform'] == 'PSV', 'General_Platform'] = 'Sony_Playstation'
base_vgs_df.loc[base_vgs_df['Platform'] == 'Wii', 'General_Platform'] = 'Nintendo'
base_vgs_df.loc[base_vgs_df['Platform'] == 'DS', 'General_Platform'] = 'Nintendo'
base_vgs_df.loc[base_vgs_df['Platform'] == 'GBA', 'General_Platform'] = 'Nintendo'
base_vgs_df.loc[base_vgs_df['Platform'] == '3DS', 'General_Platform'] = 'Nintendo'
base_vgs_df.loc[base_vgs_df['Platform'] == 'WiiU', 'General_Platform'] = 'Nintendo'
base_vgs_df.loc[base_vgs_df['Platform'] == 'NES', 'General_Platform'] = 'Nintendo'
base_vgs_df.loc[base_vgs_df['Platform'] == 'SNES', 'General_Platform'] = 'Nintendo'
base_vgs_df.loc[base_vgs_df['Platform'] == 'N64', 'General_Platform'] = 'Nintendo'
base_vgs_df.loc[base_vgs_df['Platform'] == 'GB', 'General_Platform'] = 'Nintendo'
base_vgs_df.loc[base_vgs_df['Platform'] == 'GC', 'General_Platform'] = 'Nintendo'
base_vgs_df.loc[base_vgs_df['Platform'] == 'X360', 'General_Platform'] = 'Microsoft_Xbox'
base_vgs_df.loc[base_vgs_df['Platform'] == 'XB', 'General_Platform'] = 'Microsoft_Xbox'
base_vgs_df.loc[base_vgs_df['Platform'] == 'XOne', 'General_Platform'] = 'Microsoft_Xbox'
base_vgs_df.loc[base_vgs_df['Platform'] == '2600', 'General_Platform'] = 'other'##'Atari'
base_vgs_df.loc[base_vgs_df['Platform'] == 'DC', 'General_Platform'] = 'Sega'
base_vgs_df.loc[base_vgs_df['Platform'] == 'SAT', 'General_Platform'] = 'Sega'
base_vgs_df.loc[base_vgs_df['Platform'] == 'GG', 'General_Platform'] = 'Sega'
base_vgs_df.loc[base_vgs_df['Platform'] == 'WS', 'General_Platform'] = 'other'##'Bandal'
base_vgs_df.loc[base_vgs_df['Platform'] == 'TG16', 'General_Platform'] = 'other'##'Nec'
base_vgs_df.loc[base_vgs_df['Platform'] == 'PCFX', 'General_Platform'] ='other'## 'Nec'
base_vgs_df.loc[base_vgs_df['Platform'] == '3DO', 'General_Platform'] = 'other'##'Panasonic'
base_vgs_df.loc[base_vgs_df['Platform'] == 'PC', 'General_Platform'] = 'PC'
base_vgs_df.loc[base_vgs_df['Platform'] == 'GEN', 'General_Platform'] = 'other'##'GEN'
base_vgs_df.loc[base_vgs_df['Platform'] == 'NG', 'General_Platform'] = 'other'##'NG'
base_vgs_df.loc[base_vgs_df['Platform'] == 'SCD', 'General_Platform'] = 'other'##'SCD'

base_vgs_df["General_Platform"].unique()
# Out:
# array(['Nintendo', 'Microsoft_Xbox', 'Sony_Playstation', 'PC', 'other',
#        'Sega'], dtype=object)

# %%
## converted categorical data in Genre column to numerical in order to see if there is any correlation to games sold in NA

# %%time
thisdict = {
   "Sports": int(1),
    "Platform": int(2),
    "Racing": int(3),
    "Role-Playing":int(4),
    'Puzzle' : int(12),
    "Misc" :int(5),
    "Shooter":int(6), 
    "Simulation": int(7), 
    "Action":int(8), 
    "Fighting":int(9), 
    "Adventure":int(10),
    "Strategy":int(11)
}

std_vgs_df = base_vgs_df.dropna(axis=1, thresh = 16000).dropna().reset_index(drop = True).astype({'Year_of_Release': 'int32'})
full_arr = []

def partial_arr(arr, lis):
    temp = arr.index.start
    for name in arr:
        arr[temp] = thisdict[name]
        temp = temp +1
    lis.append(arr)
    
temp_arr = std_vgs_df['Genre']

processes = []
list_of_arrays = np.split(temp_arr, 4)

if __name__ == '__main__':
    final_list= ()
    manager = multiprocessing.Manager()
    final_list = manager.list()

    for i in range(4):
        p = multiprocessing.Process(target = partial_arr(list_of_arrays[i],final_list))
        p.start()
        processes.append(p)
    for pro in processes:
        pro.join()

std_vgs_df['Genre'] = np.concatenate(final_list, axis=None)

train_std, test_std = train_test_split(std_vgs_df, test_size=0.2)

std_vgs_df.head()
# Out:
# Wall time: 924 ms
#                        Name Platform  Year_of_Release Genre Publisher  \
# 0                Wii Sports      Wii             2006     1  Nintendo
# 1         Super Mario Bros.      NES             1985     2  Nintendo
# 2            Mario Kart Wii      Wii             2008     3  Nintendo
# 3         Wii Sports Resort      Wii             2009     1  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB             1996     4  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales General_Platform
# 0     41.36     28.96      3.77         8.45         82.53         Nintendo
# 1     29.08      3.58      6.81         0.77         40.24         Nintendo
# 2     15.68     12.76      3.79         3.29         35.52         Nintendo
# 3     15.61     10.93      3.28         2.95         32.77         Nintendo
# 4     11.27      8.89     10.22         1.00         31.37         Nintendo

# %%
std_vgs_df.dtypes
# Out:
# Name                 object
# Platform             object
# Year_of_Release       int32
# Genre                object
# Publisher            object
# NA_Sales            float64
# EU_Sales            float64
# JP_Sales            float64
# Other_Sales         float64
# Global_Sales        float64
# General_Platform     object
# dtype: object

# %%
## noNA_vgs_df ==== Video Game Sales DataFrame with ALL ROWS WITH NA VALUES REMOVED

noNA_vgs_df = base_vgs_df.dropna().reset_index(drop = True).astype({'Year_of_Release': 'int32'})

temp = 0
for name in noNA_vgs_df.Genre:
    noNA_vgs_df.loc[temp, 'Genre'] = thisdict[name]
    temp = temp +1
    
noNA_vgs_df = noNA_vgs_df.astype({'Genre':int})

train_noNA, test_noNA = train_test_split(noNA_vgs_df, test_size=0.2)
noNA_vgs_df.head()
# Out:
#                     Name Platform  Year_of_Release  Genre Publisher  NA_Sales  \
# 0             Wii Sports      Wii             2006      1  Nintendo     41.36
# 1         Mario Kart Wii      Wii             2008      3  Nintendo     15.68
# 2      Wii Sports Resort      Wii             2009      1  Nintendo     15.61
# 3  New Super Mario Bros.       DS             2006      2  Nintendo     11.28
# 4               Wii Play      Wii             2006      5  Nintendo     13.96
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 0     28.96      3.77         8.45         82.53          76.0          51.0
# 1     12.76      3.79         3.29         35.52          82.0          73.0
# 2     10.93      3.28         2.95         32.77          80.0          73.0
# 3      9.14      6.50         2.88         29.80          89.0          65.0
# 4      9.18      2.93         2.84         28.92          58.0          41.0
#
# ...

# %% [markdown]
# ## Visualization <a name="visualize"></a>

# %%
## check number of releases for each platform

plt.style.use('dark_background')
fig = plt.figure(figsize = (12,5))
years =np.arange(1980,2018)

game_count_year = sb.catplot(x="Year_of_Release", data=std_vgs_df, kind="count", height=6,color = 'blue', aspect=1.5, order=years)
game_count_year.set_xticklabels(step=2)
game_count_year.set(xlabel = 'Year of Release',ylabel = 'Count of Games',title = 'Total Count of Release Games per Year')




plt.show()

# %%
yearlySales = std_vgs_df.groupby(['Year_of_Release','General_Platform']).NA_Sales.sum()
yearlySales.unstack().plot(kind='bar',stacked=True,  
                           grid=False,  figsize=(12,10))

plt.title('Barplot of North American Sales of all Game Platforms by Year')
plt.ylabel('North American Sales (in millons)')
plt.xlabel('Year of Release')
# Out:
# Text(0.5, 0, 'Year of Release')

# %% [markdown]
# ## Correlation of Features <a name="visualize"></a>

# %%
sb.heatmap(train_std.corr(), annot=True).set_title("Correlation of Attributes")
fig=plt.gcf()
fig.set_size_inches(15,15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# -check amounts of video games produced vs time
# -consider when data should start
# -fix categorical data so can be put in heatmap
# -focus is NA sales

# %%
sb.heatmap(train_noNA.corr(), annot=True).set_title("Correlation of Attributes")
fig=plt.gcf()
fig.set_size_inches(15,15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
