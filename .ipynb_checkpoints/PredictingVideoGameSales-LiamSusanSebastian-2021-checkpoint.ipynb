# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
import multiprocessing

# %% [markdown]
# # PREDICTING NORTH AMERICAN VIDEO GAME SALES
#
# ## Table Of Contents
# 1. [Understanding and Preparing](#preprocess)
# 3. [Visualizing the Data](#visualize)
# 4. [Correlation of Features](#correlation)
# 5. [Training our NaiveBayes Model](#trainingModel0)

# %% [markdown]
# ## Understanding and Preparing the Data <a name="preprocess"></a>
#
# First we read the data which is in a csv file into a dataframe,

# %%
## base_vgs_df ==== Base Video Game Sales DataFrame

base_vgs_df = pd.read_csv('../VideoGameSalesProject2021/Video_Games_Sales_as_at_22_Dec_2016.csv')

base_vgs_df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0          51.0         8.0       322.0  Nintendo      E
# 1           NaN         NaN         NaN       NaN    NaN
# 2          73.0         8.3       709.0  Nintendo      E
# 3          73.0         8.0       192.0  Nintendo      E
# 4           NaN         NaN         NaN       NaN    NaN

# %% [markdown]
# Then we checked for any missing or incorrect values and got an idea of the contents in each of the columns.

# %%
## checking for missing values by adding up all missing values in each column
base_vgs_df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher           255
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
base_vgs_df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count   User_Score  \
# count  16719.000000  16719.000000   8137.000000   8137.000000  7590.000000
# mean       0.047332      0.533543     68.967679     26.360821     7.125046
# std        0.186710      1.547935     13.938165     18.980495     1.500006
# min        0.000000      0.010000     13.000000      3.000000     0.000000
# 25%        0.000000      0.060000     60.000000     12.000000     6.400000
# 50%        0.010000      0.170000     71.000000     21.000000     7.500000
# 75%        0.030000      0.470000     79.000000     36.000000     8.200000
# max       10.570000     82.530000     98.000000    113.000000     9.700000
#
#          User_Count
# count   7590.000000
# mean     162.229908
# std      561.282326
# min        4.000000
# 25%       10.000000
# 50%       24.000000
# 75%       81.000000
# max    10665.000000

# %% [markdown]
# We can see that the following columns are missing a significant portion of data; Critic_score, critic_count, User_Score, User_Count, Developer, and Rating so we will have to deal with that eventually. Also notice that there are a couple other issues with the data in the columns,
#
# - The max value in Year_of_Release is 2020, which must be pre-release or something of that nature
# - Large difference between the max and the rest of the data in all the sales columns

# %%
#inspect the sales column
base_vgs_df['dummy'] = np.ones(base_vgs_df['Platform'].size)
freq_NA_sales = base_vgs_df.groupby("NA_Sales")['dummy'].count()

plt.figure(figsize=(10, 6))

plt.plot(freq_NA_sales)
plt.ylabel('Number of Games')
plt.xlabel('NA Sales (in millions)')
plt.title('Frequency of NA Sales')
plt.xlim(0, 10)
plt.ylim(0,800)
plt.grid()

#base_vgs_df['NA_Sales'] = base_vgs_df['NA_Sales'].replace({0.00 : None})

#base_vgs_df = base_vgs_df.dropna(subset =['NA_Sales']).reset_index()

#base_vgs_df['NA_Sales']

# %% [markdown]
# Here we see the frequency of NA Sales is super high close to 0 and is very small anywhere beyond 2. We can see that this is an exponential distribution so a log transform could be useful if trying to normalize this data. Assuming that the games that sold zero copies in North America are the ones that are 0.00, we can drop these values.

# %%
base_vgs_df.nlargest(5, 'Year_of_Release')
# Out:
#                                                    Name Platform  \
# 5936                             Imagine: Makeup Artist       DS
# 14086  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16222  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16385                  Brothers Conflict: Precious Baby      PSV
# 94                                              FIFA 17      PS4
#
#        Year_of_Release         Genre        Publisher  NA_Sales  EU_Sales  \
# 5936            2020.0    Simulation          Ubisoft      0.27      0.00
# 14086           2017.0  Role-Playing             Sega      0.00      0.00
# 16222           2017.0  Role-Playing             Sega      0.00      0.00
# 16385           2017.0        Action     Idea Factory      0.00      0.00
# 94              2016.0        Sports  Electronic Arts      0.66      5.75
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 5936       0.00         0.02          0.29           NaN           NaN
# 14086      0.04         0.00          0.04           NaN           NaN
# 16222      0.01         0.00          0.01           NaN           NaN
# 16385      0.01         0.00          0.01           NaN           NaN
# 94         0.08         1.11          7.59          85.0          41.0
#
#        User_Score  User_Count                Developer Rating  dummy
# 5936          NaN         NaN                  Ubisoft      E    1.0
# 14086         NaN         NaN                      NaN    NaN    1.0
# 16222         NaN         NaN                      NaN    NaN    1.0
# 16385         NaN         NaN                      NaN    NaN    1.0
# 94            5.0       398.0  EA Sports, EA Vancouver      E    1.0

# %% [markdown]
# We can see that there were only a couple games with a date of release after 2016 so we will drop these values.
#
# An important thing to note when considering these video game sales is what consoles were being released at the time. We agreed that if we want to find the most accurate predictors of NA sales in the future we should look data is the immediate past as the video gaming seen has changed drastically from when it started. But where do we start? We see a peak near 2008, this was when the Wii, Xbox 360, and Playstation 3 came out. These consoles are slowly going out of fashion so let's drop games released after these consoles came out. We see a decline in console games which is certaintly a trend that is most important for us to capture.

# %% [markdown]
# ## Visualization <a name="visualize"></a>
#
# In order to visualize the data we are going to make all the changes listed above. Here is what they are,
#
# - Drop columns that are missing over 50% of the values i.e. Critic_score, critic_count, User_Score, User_Count, Developer, and Rating
#
# - Drop rows with missing values in any column that is not one of the ones listed above
#
# - Drop all rows with the year of release below or above the range 2009-2016
#
# - (Optional) Normalize NA_Sales as it shows an exponential distribution

# %%
std_vgs_df = base_vgs_df.dropna(axis=1, thresh = 9000).dropna().reset_index(drop = True)
std_vgs_df = std_vgs_df[std_vgs_df.Year_of_Release > 2008.0]
std_vgs_df = std_vgs_df[std_vgs_df.Year_of_Release < 2017.0]
std_vgs_df = std_vgs_df[std_vgs_df.NA_Sales != 0.00].reset_index(drop = True)

# %% [markdown]
# We are also going to add an additional column titled 'General_Platform' which we will use in the following graphs,

# %%
std_vgs_df['Platform'].unique()
# Out:
# array(['Wii', 'X360', 'PS3', '3DS', 'PS4', 'PC', 'WiiU', 'DS', 'XOne',
#        'PSP', 'PS2', 'PSV'], dtype=object)

# %%
## create general platform column

std_vgs_df['General_Platform']= base_vgs_df['Platform']

std_vgs_df.loc[std_vgs_df['Platform'] == 'PS3', 'General_Platform'] =  'Sony_Playstation'
std_vgs_df.loc[std_vgs_df['Platform'] == 'PS', 'General_Platform'] = 'Sony_Playstation' 
std_vgs_df.loc[std_vgs_df['Platform'] == 'PS2', 'General_Platform'] = 'Sony_Playstation'
std_vgs_df.loc[std_vgs_df['Platform'] == 'PS4', 'General_Platform'] = 'Sony_Playstation'
std_vgs_df.loc[std_vgs_df['Platform'] == 'PSP', 'General_Platform'] = 'Sony_Playstation'
std_vgs_df.loc[std_vgs_df['Platform'] == 'PSV', 'General_Platform'] = 'Sony_Playstation'
std_vgs_df.loc[std_vgs_df['Platform'] == 'Wii', 'General_Platform'] = 'Nintendo'
std_vgs_df.loc[std_vgs_df['Platform'] == 'DS', 'General_Platform'] = 'Nintendo'
std_vgs_df.loc[std_vgs_df['Platform'] == 'GBA', 'General_Platform'] = 'Nintendo'
std_vgs_df.loc[std_vgs_df['Platform'] == '3DS', 'General_Platform'] = 'Nintendo'
std_vgs_df.loc[std_vgs_df['Platform'] == 'WiiU', 'General_Platform'] = 'Nintendo'
std_vgs_df.loc[std_vgs_df['Platform'] == 'NES', 'General_Platform'] = 'Nintendo'
std_vgs_df.loc[std_vgs_df['Platform'] == 'X360', 'General_Platform'] = 'Microsoft_Xbox'
std_vgs_df.loc[std_vgs_df['Platform'] == 'XOne', 'General_Platform'] = 'Microsoft_Xbox'
std_vgs_df.loc[std_vgs_df['Platform'] == 'PC', 'General_Platform'] = 'PC'

# %% [markdown]
# We can see that although these graphs gives us some idea about the number of games produced for each platform vs the number of sales for each platform, there are a lot of platforms and it gets confusing. In order to deal with this, we will group the platforms more generally.

# %%
plt.style.use('dark_background')
temp_df = std_vgs_df.groupby(['Year_of_Release', 'General_Platform'])[['dummy','NA_Sales']].sum()
temp_df['avg_sales'] = temp_df['NA_Sales'].div(temp_df['dummy'])



fig, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)

temp_df['dummy'].unstack().plot(ax= axes[0],kind='bar',stacked=True,  
                           grid=False,  figsize=(12,10), cmap = 'PuBu')

temp_df['NA_Sales'].unstack().plot(ax= axes[1],kind='bar',stacked=True,  
                           grid=False,  figsize=(12,10), cmap = 'PuRd')

temp_df['avg_sales'].unstack().plot(ax= axes[2],kind='bar',stacked=True,  
                           grid=False,  figsize=(12,10), cmap = 'GnBu')

axes[0].set_title('Number of Games Produced by General Platform Per Year')
axes[0].set_ylabel('Number of Games')
axes[0].set_xlabel('Year of Release')
axes[1].set_title('Sum of North American Sales By General Platforms Per Year')
axes[1].set_ylabel('North American Sales (in millons)')
axes[1].set_xlabel('Year of Release')
axes[2].set_title('Average Sales per Game by General Platform Per Year')
axes[2].set_ylabel('Average North American Sales (in millons)')
axes[2].set_xlabel('Year of Release')
# Out:
# Text(0.5, 0, 'Year of Release')

# %% [markdown]
# Now we examine the amount of North American sales each publisher had to determine what publishers have done the best. We have taken  the average amount of sales by publishers to avoid dealing with differences in amounts of games produced.

# %%
games_by_genre_total = std_vgs_df.groupby(['Genre'])[['dummy','NA_Sales']].sum()
games_by_genre_total['avg_sales'] = games_by_genre_total['dummy'].div(games_by_genre_total['NA_Sales'])

fig, axes = plt.subplots(2, 1, figsize=(12, 8), sharex=True)

sb.barplot(ax = axes[0], x = games_by_genre_total.index, y=games_by_genre_total['dummy'], color = 'blue')
sb.barplot(ax = axes[1], x = games_by_genre_total.index, y=games_by_genre_total['avg_sales'], color = 'green')


axes[0].set_title('Total Games Produced by Genre')
axes[1].set_title('Average Sales by Genre')
axes[0].set_ylabel('Number of Games')
axes[0].grid(b = True, color = '#666666')
axes[1].grid(b = True, color = '#666666')

# %%
publisher_df = std_vgs_df.groupby(['Publisher'])[['dummy','NA_Sales']].sum()
publisher_df['avg_sales'] = publisher_df['NA_Sales'].div(publisher_df['dummy'])
avg_publisher_df = publisher_df[publisher_df['avg_sales']>= 0.355014] ##top 20 publishers

fig, axes = plt.subplots(1, 1, figsize=(10, 9), sharex=True)

sb.barplot(x = avg_publisher_df.index, y= avg_publisher_df['avg_sales'], color = 'purple')

fig.autofmt_xdate()
for tick in axes.get_xticklabels():
    tick.set_rotation(45)
axes.grid(b = True, color = '#666666')
axes.set_title('Average Sales by Publisher per Game')
# Out:
# Text(0.5, 1.0, 'Average Sales by Publisher per Game')

# %%
std_vgs_df.head()
# Out:
#                         Name Platform  Year_of_Release     Genre  \
# 0          Wii Sports Resort      Wii           2009.0    Sports
# 1  New Super Mario Bros. Wii      Wii           2009.0  Platform
# 2         Kinect Adventures!     X360           2010.0      Misc
# 3               Wii Fit Plus      Wii           2009.0    Sports
# 4         Grand Theft Auto V      PS3           2013.0    Action
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                Nintendo     15.61     10.93      3.28         2.95
# 1                Nintendo     14.44      6.94      4.70         2.24
# 2  Microsoft Game Studios     15.00      4.89      0.24         1.69
# 3                Nintendo      9.01      8.49      2.53         1.77
# 4    Take-Two Interactive      7.02      9.09      0.98         3.96
#
#    Global_Sales            Developer Rating  dummy  General_Platform
# 0         32.77             Nintendo      E    1.0          Nintendo
# 1         28.32             Nintendo      E    1.0          Nintendo
# 2         21.81  Good Science Studio      E    1.0    Microsoft_Xbox
# 3         21.79             Nintendo      E    1.0          Nintendo
# 4         21.04       Rockstar North      M    1.0  Sony_Playstation

# %% [markdown]
# # Naive Bayes Set-Up

# %%
## average NA sales
midpoint_sales = std_vgs_df['NA_Sales'].describe()['50%'] ## this midpoint is the .5 quartile marker, so better than this is better than half of all the games produced
base_probability = std_vgs_df[std_vgs_df['NA_Sales']> midpoint_sales]['NA_Sales'].size / std_vgs_df['NA_Sales'].size

std_vgs_df['good_or_bad'] = np.zeros(std_vgs_df['NA_Sales'].size)

std_vgs_df.loc[std_vgs_df['NA_Sales'] >= midpoint_sales, 'good_or_bad'] = 1
        
tempor1 = pd.get_dummies(std_vgs_df.Genre, prefix = 'Genre')
tempor2 = pd.get_dummies(std_vgs_df.Publisher, prefix = 'Publisher')
tempor3 = pd.get_dummies(std_vgs_df.Developer, prefix = 'Developer')
tempor4 = pd.get_dummies(std_vgs_df.Platform, prefix = 'Platform')

std_vgs_df = pd.concat([std_vgs_df, tempor1, tempor2, tempor3, tempor4], axis = 1)

final_data = std_vgs_df.drop(['good_or_bad','Name', 'Platform', 'Year_of_Release','Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Developer', 'Rating', 'dummy', 'General_Platform'], axis=1)

#final_data.astype('float64').dtypes
Y = list(std_vgs_df.good_or_bad.values)

final_data.dtypes

#we are going to fit our data to a Naive Bayes model that will tell us whether or not a video games will do better than average in NA sales
X_train, X_test, y_train, y_test = train_test_split(final_data.reset_index(drop=True), Y, test_size=0.5, random_state=0)
gnb = GaussianNB()
y_pred = gnb.fit(X_train, y_train).predict(X_test)
print("Number of mislabeled points out of a total %d points : %d"
      % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 1808 points : 727

# %%
y_pred.ge
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-143897e4a510> in <module>
#       1 p = gnb.fit(X_train, y_train).predict_proba(X_test)
# ----> 2 p.describe()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'

# %%
## converted categorical data in Genre column to numerical in order to see if there is any correlation to games sold in NA
thisdict = {
   "Sports": int(1),
    "Platform": int(2),
    "Racing": int(3),
    "Role-Playing":int(4),
    'Puzzle' : int(12),
    "Misc" :int(5),
    "Shooter":int(6), 
    "Simulation": int(7), 
    "Action":int(8), 
    "Fighting":int(9), 
    "Adventure":int(10),
    "Strategy":int(11)
}

test1_df = std_vgs_df
full_arr = []

def partial_arr(arr, lis):
    temp = arr.index.start
    for name in arr:
        arr[temp] = thisdict[name]
        temp = temp +1
    lis.append(arr)
    
temp_arr = test1_df['Genre']

processes = []
multiple_of_arr_size = 3
list_of_arrays = np.split(temp_arr, multiple_of_arr_size)

if __name__ == '__main__':
    final_list= ()
    manager = multiprocessing.Manager()
    final_list = manager.list()

    for i in range(multiple_of_arr_size):
        p = multiprocessing.Process(target = partial_arr(list_of_arrays[i],final_list))
        p.start()
        processes.append(p)
    for pro in processes:
        pro.join()

test1_df['Genre'] = np.concatenate(final_list, axis=None)

train_std, test_std = train_test_split(test1_df, test_size=0.2)

test1_df['Publisher'].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Activision', 'Sony Computer Entertainment', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', '505 Games',
#        'Sony Computer Entertainment Europe',
#        'Warner Bros. Interactive Entertainment', 'Square Enix', 'Capcom',
#        'Sega', 'Eidos Interactive', 'Namco Bandai Games',
#        'Konami Digital Entertainment', 'MTV Games',
#        'Disney Interactive Studios', 'Majesco Entertainment', 'THQ',
#        'Deep Silver', 'NCSoft', 'Valve Software', 'Mindscape',
#        'LucasArts', 'Valve', 'Hello Games', 'Activision Value',
#        'Codemasters', 'Zoo Games', 'Focus Home Interactive',
#        'City Interactive', 'Atlus', 'Mastertronic',
#        'Slightly Mad Studios', 'Marvelous Entertainment', 'Tecmo Koei',
#        'Mojang', 'Square Enix ', 'Atari', 'Ubisoft Annecy', 'Level 5',
#        'Hudson Soft', 'Avanquest Software', 'Big Ben Interactive',
#        'Nippon Ichi Software', 'Sony Computer Entertainment America',
#        'Funbox Media', 'GSP', 'Rondomedia', 'Ghostlight', 'Spike',
#        'Rising Star Games', 'PQube', 'Trion Worlds', 'Xseed Games',
#        'SouthPeak Games', 'Natsume', 'Destineer',
#        'Sony Online Entertainment', 'XS Games', 'Harmonix Music Systems',
#        'Activision Blizzard', 'Telltale Games', 'GameMill Entertainment',
#        'D3Publisher', 'Knowledge Adventure', 'Tetris Online', 'Mastiff',
#        'GungHo', 'Mentor Interactive', 'Avanquest', 'Black Bean Games',
#        'Koch Media', 'ChunSoft', 'Scholastic Inc.', 'PopCap Games',
#        'Zushi Games', 'Marvelous Interactive', 'Storm City Games',
#        'Kalypso Media', 'Home Entertainment Suppliers',
#        'Arc System Works', 'Banpresto', 'Ignition Entertainment',
#        'Little Orbit', 'FuRyu', 'Vivendi Games',
#        'Nihon Falcom Corporation', 'DTP Entertainment',
#        'Falcom Corporation', 'Nordcurrent', 'Nordic Games',
#        'Milestone S.r.l.', 'Zoo Digital Publishing',
#        'Crave Entertainment', 'Gamebridge', 'Rebellion Developments',
#        'Agatsuma Entertainment', 'Aspyr', 'JoWood Productions',
#        'Foreign Media Games', 'bitComposer Games', 'Astragon',
#        'Performance Designed Products', 'UFO Interactive', 'Funcom',
#        'PlayV', 'Screenlife', 'Playlogic Game Factory', 'Game Life',
#        'Compile Heart', 'Telegames', 'System 3', 'Vir2L Studios',
#        'Neko Entertainment', 'Game Factory', 'The Adventure Company',
#        'EA Games', 'Takara Tomy', 'Nobilis', 'Yacht Club Games',
#        'Tripwire Interactive', 'DreamCatcher Interactive',
#        'Tomy Corporation', 'Idea Factory', 'Slitherine Software',
#        'Graffiti', 'Tru Blu Entertainment', 'Crytek', 'Gust', 'Acquire',
#        'Bigben Interactive', 'Idea Factory International', 'ValuSoft',
#        'O-Games', 'PM Studios', 'Reef Entertainment', 'Aqua Plus',
#        'Oxygen Interactive', 'Ackkstudios', 'inXile Entertainment',
#        'AQ Interactive', 'Enjoy Gaming ltd.', 'CCP', 'Phantom EFX',
#        'Conspiracy Entertainment', 'Blast! Entertainment Ltd',
#        'Evolved Games', 'Griffin International', 'Hudson Entertainment',
#        'Sunsoft', 'Valcon Games', 'Abylight', 'Insomniac Games',
#        'Aksys Games', 'Data Design Interactive', 'Mad Catz',
#        'Paradox Interactive', 'Tivola', 'Cave',
#        'Midas Interactive Entertainment', 'WayForward Technologies',
#        '1C Company', 'MLB.com', 'Dusenberry Martin Racing',
#        'Asylum Entertainment', 'Tradewest', 'Phenomedia', 'Tommo',
#        'Cloud Imperium Games Corporation', 'Flashpoint Games',
#        'DHM Interactive', '5pb', 'Virtual Play Games', 'Agetec',
#        'Iceberg Interactive', 'Magix', 'Games Workshop',
#        'Maximum Family Games', 'Gearbox Software',
#        'Extreme Entertainment Group', 'FuRyu Corporation',
#        'Her Interactive', 'Introversion Software', 'Sold Out',
#        'CyberFront', 'RTL', 'Microids', 'CDV Software Entertainment',
#        'P2 Games', 'Jack of All Games', 'Epic Games', 'Stainless Games',
#        'Masque Publishing', 'Visco', 'NovaLogic', 'Aerosoft',
#        'Interworks Unlimited, Inc.', 'From Software'], dtype=object)

# %%
std_vgs_df['Developer'].unique().size
# Out:
# 867
